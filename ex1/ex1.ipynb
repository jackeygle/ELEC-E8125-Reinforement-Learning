# %% [markdown]
# <div class="alert alert-block alert-info">
#    <h2 align="center"> <center><b> Reinforcement Learning Assignment 1 - The Reinforcement Learning Framework</b></center></h2>
#
# <br>
# <center><font size="3">This notebook is a part of teaching material for ELEC-E8125</font></center>
# <center><font size="3">Sep 1, 2025 - Dec 1, 2025</font></center>
# <center><font size="3">Aalto University</font></center>
# </div>
#
#
# <a id='TOC'></a>
#
# <div class="alert alert-block alert-success">
#
# # Table of contents
# * <a href='#1.'> 1. Introduction </a>
# * <a href='#1.1'> 1.1 Learning Objectives </a>
# * <a href='#1.2'> 1.2 Code Structure & Files </a>
# * <a href='#2.'> 2. Cartpole</a>
# * <a href='#3.'> 3. Reacher</a>
# * <a href='#4.'> 4. Submitting </a>
# * <a href='#4.1'> 4.1 Feedback </a>
# * <a href='#5.'> References</a>
#
# <a href='#T1'><b>Student Task 1.</b> Training a Model for Simple Cartpole Environment (10 points)</a>\
# <a href='#Q1'><b>Student Question 1.1</b> Learning (10 points)</a>\
# <a href='#T2'><b>Student Task 2.</b> Investigating Training Performance (12 points) </a>\
# <a href='#Q2'><b>Student Question 2.1</b> Analysis of Training Performance (15 points) </a>\
# <a href='#Q3'><b>Student Question 2.2</b> Stochasticity (10 points) </a>\
# <a href='#T3'><b>Student Task 3.</b> Reward Functions (20 points) </a>\
# <a href='#T4'><b>Student Task 4.</b> Visualizing Behavior </a>\
# <a href='#Q4'><b>Student Question 4.1</b> Achieved Peformance (5 points)</a>\
# <a href='#Q5'><b>Student Question 4.2</b> Analysis of Behaviour (9 points)</a>\
# <a href='#Q6'><b>Student Question 4.3</b> Checking your knowledge about RL (9 points)</a>
#
# **Total Points:** 100
#
# **Estimated runtime of all the cells:** 30 minutes

# %% [markdown]
# # 1. Introduction <a id='1.'></a>
# In this exercise we will take a first look at a reinforcement learning environment, its components and modify the reward function of a simple agent.
#
# In this notebook two environments are used: Cartpole and Reacher. The cartpole environment is taken from [OpenAI's Gym library](https://www.gymlibrary.dev/). The reacher environment is custom made (and defined in ```reacher.py```) but utilizes the Gym API.
#
# ## 1.1 Learning Objectives: <a id='1.1'></a>
# - To become familiar with assignment structure and the agent-environment relationshp
# - To understand the effects of stochasticity
# - To understand and explore the effects of task definition
#
# ## 1.2 Code Structure & Files <a id='1.2'></a>
#
# The ```train.py``` file instantiates the environment and the RL agent that acts in it. The ```agent.py``` file contains the implementation of a simple reinforcement learning agent; for the sake of this exercise, you can assume it to be a black box (you don’t need to understand how it works, although you are encouraged to study it in more detail). You don’t have to edit any other file other than ```ex1.ipynb``` to complete this exercise.
# ```
# ├───cfg                  # Config files for environments e.g. define the maximum number of steps in an episode.
# ├───imgs                 # Images used in notebook
# ├───results
# │   ├───logging          # Contains logged data
# │   ├───model            # Contains the policies learned
# │   └───video            # Contains videos for each environment
# │       └───CartPole-v0
# │       │  └───test      # Videos saved during testing
# │       │  └───train     # Videos saved during training
# │       └───SpinningReacher-v0
# │           └───test
# │           └───train
# │   ex1.ipynb            # Main assignment file containing tasks <---------
# │   feedback.ipynb       # Please give feedback in here
# │   README.ipynb         # This file
# │   agent.py             # Contains functions that govern the policy
# │   reacher.py           # Defines the reacher environment
# │   train.py             # Contains training and testing functions
# │   utils.py             # Contains useful functions
# ```

# %% [markdown]
# Please consult ```README.md``` for more details the assignments.

# %% [markdown]
# ## Warnings:
#
# - Don’t copy and paste cells within a notebook. This will mess up the tracking metadata and prevent autograding from working.
# - Only add new cells using the '+' button in the upper toolbar and do not split cells.
# - Be cautious about things such as copying the whole notebook to Colab to work on it. This has sometimes resulted in removing all notebook metadata, making autograding impossible.

# %%
skip_training = True  # Set this flag to True before validation and submission

# %%
from pathlib import Path # to find directory
work_dir = Path().cwd()/'results'
import os

import train as t # for training
import utils as u # helper functions

import numpy as np # The numpy library can be used for math functions
import torch # Used to manage policy and learning
from IPython.display import Video, display, HTML # to display videos

# %% [markdown]
# # 2. Cartpole <a id='2.'></a>
#
# The Cartpole environment consists of a cart and a pole mounted on top of it, as shown in Figure 1. The cart can move either to the left or to the right. The goal is to balance the pole in a vertical position in order to prevent it from falling down. The cart should also stay within limited distance from the center (trying to move outside screen boundaries is considered a failure).
#
# <figure>
# <img src="imgs/cartpole.png" width="400px">
# <figcaption style="text-align: center"> Figure 1: The Cartpole environment  </figcaption>
# </figure>
#
# The state and the observation are four element vectors:
#
# $$
# o=s=\left(\begin{array}{c}
# x \\
# \dot{x} \\
# \theta \\
# \dot{\theta}
# \end{array}\right) \text {, }
# $$
#
# where $x$ is the position of the cart, $\dot{x}$ is its velocity, $\theta$ is the angle of the pole w.r.t. the vertical axis, and $\dot{\theta}$ is the angular velocity of the pole.
#
# In the standard formulation, a reward of 1 is given for every timestep the pole remains balanced. Upon failing (the pole falls) or completing the task, an episode is finished.
#
# The training script will record videos of the agent’s learning progress during training, and the recorded videos are saved to ```results/video/CartPole-v0/train```. By default, the training information is saved to ```results/logging/CartPole-v0_{seed}.csv```. When the training is finished, the models are saved to ```results/model/Cartpole-v0_params.pt```. Videos of the agent’s behaviour during testing are saved to ```results/video/CartPole-v0/test```.

# %% [markdown]
# <a id='T1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 1.</b> Training a Model for Simple Cartpole Environment (10 points) </h3>
#
# This task requires you to train a model for the cartpole environment with 100 timesteps per episode. Then test the model for 500 timesteps and report average reward. To do this, you can simply run the code in the cells below.
#
# To see a full list of options that can be passed through ```cfg_args``` consult the configuation file found in ```cfg/```.
#
# - **1st** Run training over 100 steps per episode by using ```t.train``` function. See the cell below. The training will run for 500 episodes automatically.
# - **2nd:** Export the training plot ```episodesep_reward``` from logged data (.csv format).
# - **3rd:** Run testing over 500 steps by using ```t.test``` function. See the cell below. See the cell below. Notice ```max_episode_steps``` parameter.
# - **4th:** **Manually** report the average reward after the cells have completed execution.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
if not skip_training:
    t.train(cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', cfg_args=dict(seed=1, max_episode_steps=100, model_name="CartPole-v1")) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  1
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:87: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2025/ex1/results/video/CartPole-v1/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Configuration Settings: {'exp_name': 'ex1', 'seed': 1, 'env_name': 'CartPole-v1', 'model_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 14.0 (14 timesteps)
# Episode 5 finished. Total reward: 38.0 (38 timesteps)
# Episode 10 finished. Total reward: 14.0 (14 timesteps)
# Episode 15 finished. Total reward: 83.0 (83 timesteps)
# Episode 20 finished. Total reward: 12.0 (12 timesteps)
# Episode 25 finished. Total reward: 18.0 (18 timesteps)
# Episode 30 finished. Total reward: 36.0 (36 timesteps)
# Episode 35 finished. Total reward: 16.0 (16 timesteps)
# Episode 40 finished. Total reward: 29.0 (29 timesteps)
# Episode 45 finished. Total reward: 15.0 (15 timesteps)
# Episode 50 finished. Total reward: 15.0 (15 timesteps)
# Episode 55 finished. Total reward: 27.0 (27 timesteps)
# Episode 60 finished. Total reward: 33.0 (33 timesteps)
# Episode 65 finished. Total reward: 11.0 (11 timesteps)
# Episode 70 finished. Total reward: 27.0 (27 timesteps)
# Episode 75 finished. Total reward: 13.0 (13 timesteps)
# Episode 80 finished. Total reward: 9.0 (9 timesteps)
# Episode 85 finished. Total reward: 19.0 (19 timesteps)
# Updating the policy...
# Updating finished!
# Episode 90 finished. Total reward: 58.0 (58 timesteps)
# Episode 95 finished. Total reward: 13.0 (13 timesteps)
# Episode 100 finished. Total reward: 17.0 (17 timesteps)
# Episode 105 finished. Total reward: 17.0 (17 timesteps)
# Episode 110 finished. Total reward: 27.0 (27 timesteps)
# Episode 115 finished. Total reward: 9.0 (9 timesteps)
# Episode 120 finished. Total reward: 17.0 (17 timesteps)
# Episode 125 finished. Total reward: 13.0 (13 timesteps)
# Episode 130 finished. Total reward: 26.0 (26 timesteps)
# Episode 135 finished. Total reward: 9.0 (9 timesteps)
# Episode 140 finished. Total reward: 89.0 (89 timesteps)
# Episode 145 finished. Total reward: 14.0 (14 timesteps)
# Episode 150 finished. Total reward: 30.0 (30 timesteps)
# Episode 155 finished. Total reward: 27.0 (27 timesteps)
# Episode 160 finished. Total reward: 23.0 (23 timesteps)
# Updating the policy...
# Updating finished!
# Episode 165 finished. Total reward: 24.0 (24 timesteps)
# Episode 170 finished. Total reward: 28.0 (28 timesteps)
# Episode 175 finished. Total reward: 32.0 (32 timesteps)
# Episode 180 finished. Total reward: 27.0 (27 timesteps)
# Episode 185 finished. Total reward: 65.0 (65 timesteps)
# Episode 190 finished. Total reward: 99.0 (99 timesteps)
# Episode 195 finished. Total reward: 30.0 (30 timesteps)
# Episode 200 finished. Total reward: 25.0 (25 timesteps)
# Episode 205 finished. Total reward: 29.0 (29 timesteps)
# Episode 210 finished. Total reward: 27.0 (27 timesteps)
# Updating the policy...
# Updating finished!
# Episode 215 finished. Total reward: 100.0 (100 timesteps)
# Episode 220 finished. Total reward: 100.0 (100 timesteps)
# Episode 225 finished. Total reward: 59.0 (59 timesteps)
# Episode 230 finished. Total reward: 74.0 (74 timesteps)
# Episode 235 finished. Total reward: 49.0 (49 timesteps)
# Episode 240 finished. Total reward: 96.0 (96 timesteps)
# Episode 245 finished. Total reward: 73.0 (73 timesteps)
# Updating the policy...
# Updating finished!
# Episode 250 finished. Total reward: 100.0 (100 timesteps)
# Episode 255 finished. Total reward: 100.0 (100 timesteps)
# Episode 260 finished. Total reward: 52.0 (52 timesteps)
# Episode 265 finished. Total reward: 100.0 (100 timesteps)
# Episode 270 finished. Total reward: 18.0 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 275 finished. Total reward: 100.0 (100 timesteps)
# Episode 280 finished. Total reward: 93.0 (93 timesteps)
# Episode 285 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 295 finished. Total reward: 100.0 (100 timesteps)
# Episode 300 finished. Total reward: 52.0 (52 timesteps)
# Episode 305 finished. Total reward: 100.0 (100 timesteps)
# Episode 310 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Episode 320 finished. Total reward: 100.0 (100 timesteps)
# Episode 325 finished. Total reward: 100.0 (100 timesteps)
# Episode 330 finished. Total reward: 100.0 (100 timesteps)
# Episode 335 finished. Total reward: 40.0 (40 timesteps)
# Episode 340 finished. Total reward: 42.0 (42 timesteps)
# Updating the policy...
# Updating finished!
# Episode 345 finished. Total reward: 100.0 (100 timesteps)
# Episode 350 finished. Total reward: 100.0 (100 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Episode 360 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 365 finished. Total reward: 100.0 (100 timesteps)
# Episode 370 finished. Total reward: 100.0 (100 timesteps)
# Episode 375 finished. Total reward: 100.0 (100 timesteps)
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 100.0 (100 timesteps)
# Episode 400 finished. Total reward: 35.0 (35 timesteps)
# Updating the policy...
# Updating finished!
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Episode 410 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Episode 425 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Episode 440 finished. Total reward: 100.0 (100 timesteps)
# Episode 445 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 98.0 (98 timesteps)
# Episode 460 finished. Total reward: 98.0 (98 timesteps)
# Episode 465 finished. Total reward: 98.0 (98 timesteps)
# Updating the policy...
# Updating finished!
# Episode 470 finished. Total reward: 100.0 (100 timesteps)
# Episode 475 finished. Total reward: 90.0 (90 timesteps)
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 490 finished. Total reward: 100.0 (100 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2025/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------

# %%
if not skip_training:
    u.plot_reward(Path().cwd()/'results'/'logging'/'CartPole-v1_1.csv', 'CartPole')

# %% [markdown]
# The command below will evaluate the trained model in 10 episodes and report the average reward (and episode length) for these 10 episodes. Do not delete the cell below as it is used for grading.

# %%
# %%capture --no-stdout
assert t.test(episodes=10, cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
        cfg_args=dict(testing=True, save_video=(not skip_training), save_model=False, seed=None, max_episode_steps=500,model_name="CartPole-v1")) > 100
# Out:
# Numpy/Torch/Random Seed:  688
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 117.0 seed: 434
# Test ep reward: 136.0 seed: 308
# Test ep reward: 125.0 seed: 922
# Test ep reward: 121.0 seed: 231
# Test ep reward: 116.0 seed: 961
# Test ep reward: 133.0 seed: 363
# Test ep reward: 124.0 seed: 626
# Test ep reward: 125.0 seed: 905
# Test ep reward: 133.0 seed: 497
# Test ep reward: 129.0 seed: 816
# Average test reward: 125.9 episode length: 125.9

# %% [markdown]
# Report below the average reward after testing the model

# %% [markdown]
# YOUR ANSWER HERE：Average test reward: 125.9 episode length: 125.9

# %% [markdown]
# The agent acting in the environment can be seen using the following command. Change the ```path``` to pick the episode you want to visualize. Bear in mind by default video saving for training is taken every 50 episodes.

# %%
if not skip_training:
    # Train Result
    video_dir = work_dir/'video'/'CartPole-v1'/'train'
    
    # List all MP4 files in the directory
    mp4_files = [file for file in os.listdir(video_dir) if file.endswith(".mp4")]
    frame_colors = ['#FF5733', '#33FF57', '#5733FF', '#FFFF33', '#33FFFF', '#FF33FF']
    # Display each MP4 file
    for i, mp4_file in enumerate(mp4_files):
        video_path = os.path.join(video_dir, mp4_file)
        video = Video(video_path, embed=True, html_attributes="loop autoplay", width=200, height=100)
        frame_color = frame_colors[i % len(frame_colors)]
        video_frame = HTML(f'<div style="width: 200px; height: 100px;; border: 1px solid #FF5733;">{video._repr_html_()}</div>')
        print("test/",mp4_file)
        display(video_frame)
# Out:
# test/ ex1-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-50.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-100.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-150.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-200.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-250.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-300.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-350.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-400.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-450.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-500.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>

# %%
if not skip_training:
    # Test Result
    
    video_dir = work_dir/'video'/'CartPole-v1'/'test'
    
    # List all MP4 files in the directory
    mp4_files = [file for file in os.listdir(video_dir) if file.endswith(".mp4")]
    frame_colors = ['#FF5733', '#33FF57', '#5733FF', '#FFFF33', '#33FFFF', '#FF33FF']
    # Display each MP4 file
    for i, mp4_file in enumerate(mp4_files):
        video_path = os.path.join(video_dir, mp4_file)
        video = Video(video_path, embed=True, html_attributes="loop autoplay", width=200, height=100)
        frame_color = frame_colors[i % len(frame_colors)]
        video_frame = HTML(f'<div style="width: 200px; height: 100px;; border: 1px solid #5733FF;">{video._repr_html_()}</div>')
        print("test/",mp4_file)
        display(video_frame)
# Out:
# test/ ex1-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-1.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-2.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-3.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-4.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-5.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-6.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-7.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-8.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-9.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>

# %% [markdown]
# <a id='Q1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 1.1</b> Learning (10 points) </h3>
#
# Test the trained model from Task 1 five times with different random seeds. Did the same model, trained to balance for 100 timesteps, learn to always balance the pole for 1000 timesteps? Why/why not?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
#Evaluate the trained model by setting 5 different random seeds chosen by you
#Type 5 different  random seeds  in eval_seeds array
eval_seeds =  [10, 42 , 100 , 200 , 500 ]

# %%
assert len(set(eval_seeds)) == 5

# %%
# %%capture --no-stdout
def question1_1_evaluate1(eval_seeds):
    mean_reward = []

    for seed in eval_seeds:
        acc_rewards = t.test(episodes=1, cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
            cfg_args=dict(testing=True,save_video=False, save_logging=False, save_model=False, 
            seed=seed, max_episode_steps=1000, model_name="CartPole-v1"))
        mean_reward.append(acc_rewards)

    return np.mean(mean_reward)

assert question1_1_evaluate1(eval_seeds) > 100
# Out:
# Numpy/Torch/Random Seed:  10
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 141.0 seed: 10
# Average test reward: 141.0 episode length: 141.0
# Numpy/Torch/Random Seed:  42
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 141.0 seed: 42
# Average test reward: 141.0 episode length: 141.0
# Numpy/Torch/Random Seed:  100
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 123.0 seed: 100
# Average test reward: 123.0 episode length: 123.0
# Numpy/Torch/Random Seed:  200
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 118.0 seed: 200
# Average test reward: 118.0 episode length: 118.0
# Numpy/Torch/Random Seed:  500
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 132.0 seed: 500
# Average test reward: 132.0 episode length: 132.0

# %% [markdown]
# ### Question:
# Did the same model consistently balance the pole for 1000 timesteps? There are multiple correct answers. Choose the one you think is most appropriate.
#
# **Options:**
# Choose **only one**:
#
# 1. No, the agent generally failed around 100-200 timesteps because it encountered unfamiliar states.
#
# 2. Yes, the agent balanced the pole for 1000 timesteps in every test due to a perfectly learned policy.
#
# 3. No, although the agent sometimes balanced the pole for 1000 timesteps, it typically failed due to limited generalization to new states.
#
# 4. No, the agent frequently moved out of bounds or the pole tilted too much, showing poor adaptation.
#
# 5. Yes, the agent demonstrated perfect control in all tests due to effective training.
#
# 6. No, the agent's performance varied significantly with different random seeds, indicating inconsistency in learned behavior.

# %%
sq1_1 = 3 # Answer question 1.1 with the appropriate answer number

# %%
assert sq1_1 in range(1,8)

# %% [markdown]
# The following cells are used for grading

# %% [markdown]
# <a id='T2'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 2.</b> Investigating Training Performance (12 points) </h3>
#
# Repeat the experiment in Task 1 five times, each time training the model from scratch with 100 timesteps and testing it for 1000 timesteps. Use a different seed number for each training/testing cycle. You can use the box below to write a small script to do this. Use the result textbox below to report the average test reward for each repeat.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# Make sure to change the model_name for each agent to the ones given and and that the respective parameter file is saved in results/model/
#
# In order to get the points for this exercise each of the agents must have a test accuracy of higher than 100.

# %%
# %%capture
# uncomment if you want to skip the output

if not skip_training:
    model_names = ["CartPole-v1-model0", "CartPole-v1-model1", "CartPole-v1-model2", "CartPole-v1-model3", "CartPole-v1-model4"]
    model_seeds = [10, 25, 42, 73, 99]  # 5 different seeds
    assert len(set(model_seeds)) == 5
    '''
    TODO: Repeat the experiment in Task 1 five times
    '''
    ########## Your code starts here ##########
  # Train 5 models with different seeds
    for i, (name, seed) in enumerate(zip(model_names, model_seeds)):
        # Train with 100 timesteps per episode
        t.train(cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
                cfg_args=dict(seed=seed, max_episode_steps=100, model_name=name))
        
        # Test with 1000 timesteps
        avg_reward = t.test(episodes=1, cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
                           cfg_args=dict(testing=True, save_video=False, save_logging=False, 
                                       save_model=False, seed=seed, max_episode_steps=1000, 
                                       model_name=name))
        print(f"Model {i} (seed={seed}): Average test reward = {avg_reward}")
    ########## Your code ends here ##########
# Out:
# Numpy/Torch/Random Seed:  10
# Configuration Settings: {'exp_name': 'ex1', 'seed': 10, 'env_name': 'CartPole-v1', 'model_name': 'CartPole-v1-model0', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 14.0 (14 timesteps)
# Episode 5 finished. Total reward: 31.0 (31 timesteps)
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:87: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2025/ex1/results/video/CartPole-v1/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episode 10 finished. Total reward: 14.0 (14 timesteps)
# Episode 15 finished. Total reward: 12.0 (12 timesteps)
# Episode 20 finished. Total reward: 9.0 (9 timesteps)
# Episode 25 finished. Total reward: 20.0 (20 timesteps)
# Episode 30 finished. Total reward: 22.0 (22 timesteps)
# Episode 35 finished. Total reward: 13.0 (13 timesteps)
# Episode 40 finished. Total reward: 20.0 (20 timesteps)
# Episode 45 finished. Total reward: 20.0 (20 timesteps)
# Episode 50 finished. Total reward: 9.0 (9 timesteps)
# Episode 55 finished. Total reward: 28.0 (28 timesteps)
# Episode 60 finished. Total reward: 29.0 (29 timesteps)
# Episode 65 finished. Total reward: 11.0 (11 timesteps)
# Episode 70 finished. Total reward: 17.0 (17 timesteps)
# Episode 75 finished. Total reward: 16.0 (16 timesteps)
# Episode 80 finished. Total reward: 33.0 (33 timesteps)
# Episode 85 finished. Total reward: 9.0 (9 timesteps)
# Episode 90 finished. Total reward: 17.0 (17 timesteps)
# Episode 95 finished. Total reward: 20.0 (20 timesteps)
# Updating the policy...
# Updating finished!
# Episode 100 finished. Total reward: 36.0 (36 timesteps)
# Episode 105 finished. Total reward: 15.0 (15 timesteps)
# Episode 110 finished. Total reward: 18.0 (18 timesteps)
# Episode 115 finished. Total reward: 32.0 (32 timesteps)
# Episode 120 finished. Total reward: 36.0 (36 timesteps)
# Episode 125 finished. Total reward: 39.0 (39 timesteps)
# Episode 130 finished. Total reward: 21.0 (21 timesteps)
# Episode 135 finished. Total reward: 29.0 (29 timesteps)
# Episode 140 finished. Total reward: 20.0 (20 timesteps)
# Episode 145 finished. Total reward: 14.0 (14 timesteps)
# Episode 150 finished. Total reward: 38.0 (38 timesteps)
# Episode 155 finished. Total reward: 45.0 (45 timesteps)
# Episode 160 finished. Total reward: 52.0 (52 timesteps)
# Episode 165 finished. Total reward: 18.0 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 170 finished. Total reward: 19.0 (19 timesteps)
# Episode 175 finished. Total reward: 14.0 (14 timesteps)
# Episode 180 finished. Total reward: 38.0 (38 timesteps)
# Episode 185 finished. Total reward: 93.0 (93 timesteps)
# Episode 190 finished. Total reward: 13.0 (13 timesteps)
# Episode 195 finished. Total reward: 100.0 (100 timesteps)
# Episode 200 finished. Total reward: 16.0 (16 timesteps)
# Episode 205 finished. Total reward: 36.0 (36 timesteps)
# Episode 210 finished. Total reward: 73.0 (73 timesteps)
# Updating the policy...
# Updating finished!
# Episode 215 finished. Total reward: 61.0 (61 timesteps)
# Episode 220 finished. Total reward: 22.0 (22 timesteps)
# Episode 225 finished. Total reward: 79.0 (79 timesteps)
# Episode 230 finished. Total reward: 48.0 (48 timesteps)
# Episode 235 finished. Total reward: 100.0 (100 timesteps)
# Episode 240 finished. Total reward: 39.0 (39 timesteps)
# Episode 245 finished. Total reward: 73.0 (73 timesteps)
# Episode 250 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 255 finished. Total reward: 71.0 (71 timesteps)
# Episode 260 finished. Total reward: 63.0 (63 timesteps)
# Episode 265 finished. Total reward: 100.0 (100 timesteps)
# Episode 270 finished. Total reward: 100.0 (100 timesteps)
# Episode 275 finished. Total reward: 60.0 (60 timesteps)
# Updating the policy...
# Updating finished!
# Episode 280 finished. Total reward: 100.0 (100 timesteps)
# Episode 285 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 100.0 (100 timesteps)
# Episode 295 finished. Total reward: 83.0 (83 timesteps)
# Updating the policy...
# Updating finished!
# Episode 300 finished. Total reward: 100.0 (100 timesteps)
# Episode 305 finished. Total reward: 100.0 (100 timesteps)
# Episode 310 finished. Total reward: 100.0 (100 timesteps)
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 320 finished. Total reward: 100.0 (100 timesteps)
# Episode 325 finished. Total reward: 48.0 (48 timesteps)
# Episode 330 finished. Total reward: 97.0 (97 timesteps)
# Episode 335 finished. Total reward: 100.0 (100 timesteps)
# Episode 340 finished. Total reward: 95.0 (95 timesteps)
# Updating the policy...
# Updating finished!
# Episode 345 finished. Total reward: 100.0 (100 timesteps)
# Episode 350 finished. Total reward: 42.0 (42 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Episode 360 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 365 finished. Total reward: 100.0 (100 timesteps)
# Episode 370 finished. Total reward: 77.0 (77 timesteps)
# Episode 375 finished. Total reward: 100.0 (100 timesteps)
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 100.0 (100 timesteps)
# Episode 400 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Episode 410 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 425 finished. Total reward: 100.0 (100 timesteps)
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Episode 440 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 445 finished. Total reward: 100.0 (100 timesteps)
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 100.0 (100 timesteps)
# Episode 460 finished. Total reward: 100.0 (100 timesteps)
# Episode 465 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 470 finished. Total reward: 100.0 (100 timesteps)
# Episode 475 finished. Total reward: 100.0 (100 timesteps)
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 490 finished. Total reward: 95.0 (95 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2025/ex1/results/model/CartPole-v1-model0_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  10
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model0_params.pt ...
# Testing...
# Test ep reward: 110.0 seed: 10
# Average test reward: 110.0 episode length: 110.0
# Model 0 (seed=10): Average test reward = 110.0
# Numpy/Torch/Random Seed:  25
# Configuration Settings: {'exp_name': 'ex1', 'seed': 25, 'env_name': 'CartPole-v1', 'model_name': 'CartPole-v1-model1', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 31.0 (31 timesteps)
# Episode 5 finished. Total reward: 14.0 (14 timesteps)
# Episode 10 finished. Total reward: 54.0 (54 timesteps)
# Episode 15 finished. Total reward: 29.0 (29 timesteps)
# Episode 20 finished. Total reward: 18.0 (18 timesteps)
# Episode 25 finished. Total reward: 11.0 (11 timesteps)
# Episode 30 finished. Total reward: 22.0 (22 timesteps)
# Episode 35 finished. Total reward: 14.0 (14 timesteps)
# Episode 40 finished. Total reward: 30.0 (30 timesteps)
# Episode 45 finished. Total reward: 18.0 (18 timesteps)
# Episode 50 finished. Total reward: 17.0 (17 timesteps)
# Episode 55 finished. Total reward: 14.0 (14 timesteps)
# Episode 60 finished. Total reward: 18.0 (18 timesteps)
# Episode 65 finished. Total reward: 12.0 (12 timesteps)
# Episode 70 finished. Total reward: 14.0 (14 timesteps)
# Episode 75 finished. Total reward: 12.0 (12 timesteps)
# Episode 80 finished. Total reward: 17.0 (17 timesteps)
# Episode 85 finished. Total reward: 31.0 (31 timesteps)
# Episode 90 finished. Total reward: 30.0 (30 timesteps)
# Updating the policy...
# Updating finished!
# Episode 95 finished. Total reward: 54.0 (54 timesteps)
# Episode 100 finished. Total reward: 35.0 (35 timesteps)
# Episode 105 finished. Total reward: 20.0 (20 timesteps)
# Episode 110 finished. Total reward: 28.0 (28 timesteps)
# Episode 115 finished. Total reward: 25.0 (25 timesteps)
# Episode 120 finished. Total reward: 42.0 (42 timesteps)
# Episode 125 finished. Total reward: 19.0 (19 timesteps)
# Episode 130 finished. Total reward: 22.0 (22 timesteps)
# Episode 135 finished. Total reward: 15.0 (15 timesteps)
# Episode 140 finished. Total reward: 22.0 (22 timesteps)
# Episode 145 finished. Total reward: 14.0 (14 timesteps)
# Episode 150 finished. Total reward: 29.0 (29 timesteps)
# Episode 155 finished. Total reward: 12.0 (12 timesteps)
# Episode 160 finished. Total reward: 19.0 (19 timesteps)
# Updating the policy...
# Updating finished!
# Episode 165 finished. Total reward: 100.0 (100 timesteps)
# Episode 170 finished. Total reward: 34.0 (34 timesteps)
# Episode 175 finished. Total reward: 100.0 (100 timesteps)
# Episode 180 finished. Total reward: 37.0 (37 timesteps)
# Episode 185 finished. Total reward: 80.0 (80 timesteps)
# Episode 190 finished. Total reward: 25.0 (25 timesteps)
# Episode 195 finished. Total reward: 57.0 (57 timesteps)
# Episode 200 finished. Total reward: 16.0 (16 timesteps)
# Episode 205 finished. Total reward: 52.0 (52 timesteps)
# Updating the policy...
# Updating finished!
# Episode 210 finished. Total reward: 11.0 (11 timesteps)
# Episode 215 finished. Total reward: 100.0 (100 timesteps)
# Episode 220 finished. Total reward: 64.0 (64 timesteps)
# Episode 225 finished. Total reward: 100.0 (100 timesteps)
# Episode 230 finished. Total reward: 99.0 (99 timesteps)
# Episode 235 finished. Total reward: 43.0 (43 timesteps)
# Episode 240 finished. Total reward: 18.0 (18 timesteps)
# Episode 245 finished. Total reward: 12.0 (12 timesteps)
# Updating the policy...
# Updating finished!
# Episode 250 finished. Total reward: 100.0 (100 timesteps)
# Episode 255 finished. Total reward: 100.0 (100 timesteps)
# Episode 260 finished. Total reward: 81.0 (81 timesteps)
# Episode 265 finished. Total reward: 96.0 (96 timesteps)
# Updating the policy...
# Updating finished!
# Episode 270 finished. Total reward: 78.0 (78 timesteps)
# Episode 275 finished. Total reward: 39.0 (39 timesteps)
# Episode 280 finished. Total reward: 31.0 (31 timesteps)
# Episode 285 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 295 finished. Total reward: 100.0 (100 timesteps)
# Episode 300 finished. Total reward: 100.0 (100 timesteps)
# Episode 305 finished. Total reward: 69.0 (69 timesteps)
# Episode 310 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Episode 320 finished. Total reward: 100.0 (100 timesteps)
# Episode 325 finished. Total reward: 100.0 (100 timesteps)
# Episode 330 finished. Total reward: 100.0 (100 timesteps)
# Episode 335 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 340 finished. Total reward: 100.0 (100 timesteps)
# Episode 345 finished. Total reward: 100.0 (100 timesteps)
# Episode 350 finished. Total reward: 100.0 (100 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 360 finished. Total reward: 100.0 (100 timesteps)
# Episode 365 finished. Total reward: 99.0 (99 timesteps)
# Episode 370 finished. Total reward: 97.0 (97 timesteps)
# Episode 375 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 96.0 (96 timesteps)
# Updating the policy...
# Updating finished!
# Episode 400 finished. Total reward: 100.0 (100 timesteps)
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Episode 410 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Episode 425 finished. Total reward: 100.0 (100 timesteps)
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 440 finished. Total reward: 100.0 (100 timesteps)
# Episode 445 finished. Total reward: 100.0 (100 timesteps)
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 460 finished. Total reward: 100.0 (100 timesteps)
# Episode 465 finished. Total reward: 100.0 (100 timesteps)
# Episode 470 finished. Total reward: 100.0 (100 timesteps)
# Episode 475 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Episode 490 finished. Total reward: 100.0 (100 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2025/ex1/results/model/CartPole-v1-model1_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  25
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model1_params.pt ...
# Testing...
# Test ep reward: 138.0 seed: 25
# Average test reward: 138.0 episode length: 138.0
# Model 1 (seed=25): Average test reward = 138.0
# Numpy/Torch/Random Seed:  42
# Configuration Settings: {'exp_name': 'ex1', 'seed': 42, 'env_name': 'CartPole-v1', 'model_name': 'CartPole-v1-model2', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 10.0 (10 timesteps)
# Episode 5 finished. Total reward: 11.0 (11 timesteps)
# Episode 10 finished. Total reward: 16.0 (16 timesteps)
# Episode 15 finished. Total reward: 15.0 (15 timesteps)
# Episode 20 finished. Total reward: 45.0 (45 timesteps)
# Episode 25 finished. Total reward: 26.0 (26 timesteps)
# Episode 30 finished. Total reward: 16.0 (16 timesteps)
# Episode 35 finished. Total reward: 26.0 (26 timesteps)
# Episode 40 finished. Total reward: 16.0 (16 timesteps)
# Episode 45 finished. Total reward: 10.0 (10 timesteps)
# Episode 50 finished. Total reward: 15.0 (15 timesteps)
# Episode 55 finished. Total reward: 13.0 (13 timesteps)
# Episode 60 finished. Total reward: 29.0 (29 timesteps)
# Episode 65 finished. Total reward: 14.0 (14 timesteps)
# Episode 70 finished. Total reward: 26.0 (26 timesteps)
# Episode 75 finished. Total reward: 9.0 (9 timesteps)
# Episode 80 finished. Total reward: 9.0 (9 timesteps)
# Episode 85 finished. Total reward: 9.0 (9 timesteps)
# Episode 90 finished. Total reward: 15.0 (15 timesteps)
# Updating the policy...
# Updating finished!
# Episode 95 finished. Total reward: 16.0 (16 timesteps)
# Episode 100 finished. Total reward: 28.0 (28 timesteps)
# Episode 105 finished. Total reward: 17.0 (17 timesteps)
# Episode 110 finished. Total reward: 12.0 (12 timesteps)
# Episode 115 finished. Total reward: 35.0 (35 timesteps)
# Episode 120 finished. Total reward: 24.0 (24 timesteps)
# Episode 125 finished. Total reward: 22.0 (22 timesteps)
# Episode 130 finished. Total reward: 34.0 (34 timesteps)
# Episode 135 finished. Total reward: 13.0 (13 timesteps)
# Episode 140 finished. Total reward: 50.0 (50 timesteps)
# Episode 145 finished. Total reward: 53.0 (53 timesteps)
# Episode 150 finished. Total reward: 30.0 (30 timesteps)
# Episode 155 finished. Total reward: 30.0 (30 timesteps)
# Episode 160 finished. Total reward: 16.0 (16 timesteps)
# Updating the policy...
# Updating finished!
# Episode 165 finished. Total reward: 35.0 (35 timesteps)
# Episode 170 finished. Total reward: 13.0 (13 timesteps)
# Episode 175 finished. Total reward: 100.0 (100 timesteps)
# Episode 180 finished. Total reward: 17.0 (17 timesteps)
# Episode 185 finished. Total reward: 34.0 (34 timesteps)
# Episode 190 finished. Total reward: 98.0 (98 timesteps)
# Episode 195 finished. Total reward: 38.0 (38 timesteps)
# Episode 200 finished. Total reward: 41.0 (41 timesteps)
# Episode 205 finished. Total reward: 27.0 (27 timesteps)
# Updating the policy...
# Updating finished!
# Episode 210 finished. Total reward: 25.0 (25 timesteps)
# Episode 215 finished. Total reward: 100.0 (100 timesteps)
# Episode 220 finished. Total reward: 100.0 (100 timesteps)
# Episode 225 finished. Total reward: 81.0 (81 timesteps)
# Episode 230 finished. Total reward: 18.0 (18 timesteps)
# Episode 235 finished. Total reward: 60.0 (60 timesteps)
# Episode 240 finished. Total reward: 22.0 (22 timesteps)
# Updating the policy...
# Updating finished!
# Episode 245 finished. Total reward: 100.0 (100 timesteps)
# Episode 250 finished. Total reward: 100.0 (100 timesteps)
# Episode 255 finished. Total reward: 95.0 (95 timesteps)
# Episode 260 finished. Total reward: 100.0 (100 timesteps)
# Episode 265 finished. Total reward: 22.0 (22 timesteps)
# Episode 270 finished. Total reward: 76.0 (76 timesteps)
# Updating the policy...
# Updating finished!
# Episode 275 finished. Total reward: 59.0 (59 timesteps)
# Episode 280 finished. Total reward: 100.0 (100 timesteps)
# Episode 285 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 95.0 (95 timesteps)
# Updating the policy...
# Updating finished!
# Episode 295 finished. Total reward: 30.0 (30 timesteps)
# Episode 300 finished. Total reward: 23.0 (23 timesteps)
# Episode 305 finished. Total reward: 53.0 (53 timesteps)
# Episode 310 finished. Total reward: 100.0 (100 timesteps)
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 320 finished. Total reward: 58.0 (58 timesteps)
# Episode 325 finished. Total reward: 100.0 (100 timesteps)
# Episode 330 finished. Total reward: 100.0 (100 timesteps)
# Episode 335 finished. Total reward: 100.0 (100 timesteps)
# Episode 340 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 345 finished. Total reward: 100.0 (100 timesteps)
# Episode 350 finished. Total reward: 100.0 (100 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Episode 360 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 365 finished. Total reward: 100.0 (100 timesteps)
# Episode 370 finished. Total reward: 100.0 (100 timesteps)
# Episode 375 finished. Total reward: 100.0 (100 timesteps)
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 100.0 (100 timesteps)
# Episode 400 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Episode 410 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 425 finished. Total reward: 100.0 (100 timesteps)
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Episode 440 finished. Total reward: 99.0 (99 timesteps)
# Updating the policy...
# Updating finished!
# Episode 445 finished. Total reward: 100.0 (100 timesteps)
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 100.0 (100 timesteps)
# Episode 460 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 465 finished. Total reward: 100.0 (100 timesteps)
# Episode 470 finished. Total reward: 100.0 (100 timesteps)
# Episode 475 finished. Total reward: 100.0 (100 timesteps)
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Episode 490 finished. Total reward: 100.0 (100 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2025/ex1/results/model/CartPole-v1-model2_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  42
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model2_params.pt ...
# Testing...
# Test ep reward: 118.0 seed: 42
# Average test reward: 118.0 episode length: 118.0
# Model 2 (seed=42): Average test reward = 118.0
# Numpy/Torch/Random Seed:  73
# Configuration Settings: {'exp_name': 'ex1', 'seed': 73, 'env_name': 'CartPole-v1', 'model_name': 'CartPole-v1-model3', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 15.0 (15 timesteps)
# Episode 5 finished. Total reward: 39.0 (39 timesteps)
# Episode 10 finished. Total reward: 26.0 (26 timesteps)
# Episode 15 finished. Total reward: 18.0 (18 timesteps)
# Episode 20 finished. Total reward: 10.0 (10 timesteps)
# Episode 25 finished. Total reward: 15.0 (15 timesteps)
# Episode 30 finished. Total reward: 10.0 (10 timesteps)
# Episode 35 finished. Total reward: 24.0 (24 timesteps)
# Episode 40 finished. Total reward: 27.0 (27 timesteps)
# Episode 45 finished. Total reward: 49.0 (49 timesteps)
# Episode 50 finished. Total reward: 19.0 (19 timesteps)
# Episode 55 finished. Total reward: 17.0 (17 timesteps)
# Episode 60 finished. Total reward: 16.0 (16 timesteps)
# Episode 65 finished. Total reward: 11.0 (11 timesteps)
# Episode 70 finished. Total reward: 10.0 (10 timesteps)
# Episode 75 finished. Total reward: 16.0 (16 timesteps)
# Episode 80 finished. Total reward: 19.0 (19 timesteps)
# Updating the policy...
# Updating finished!
# Episode 85 finished. Total reward: 14.0 (14 timesteps)
# Episode 90 finished. Total reward: 58.0 (58 timesteps)
# Episode 95 finished. Total reward: 55.0 (55 timesteps)
# Episode 100 finished. Total reward: 11.0 (11 timesteps)
# Episode 105 finished. Total reward: 57.0 (57 timesteps)
# Episode 110 finished. Total reward: 47.0 (47 timesteps)
# Episode 115 finished. Total reward: 22.0 (22 timesteps)
# Episode 120 finished. Total reward: 18.0 (18 timesteps)
# Episode 125 finished. Total reward: 14.0 (14 timesteps)
# Episode 130 finished. Total reward: 18.0 (18 timesteps)
# Episode 135 finished. Total reward: 21.0 (21 timesteps)
# Episode 140 finished. Total reward: 10.0 (10 timesteps)
# Episode 145 finished. Total reward: 27.0 (27 timesteps)
# Updating the policy...
# Updating finished!
# Episode 150 finished. Total reward: 10.0 (10 timesteps)
# Episode 155 finished. Total reward: 75.0 (75 timesteps)
# Episode 160 finished. Total reward: 19.0 (19 timesteps)
# Episode 165 finished. Total reward: 21.0 (21 timesteps)
# Episode 170 finished. Total reward: 53.0 (53 timesteps)
# Episode 175 finished. Total reward: 28.0 (28 timesteps)
# Episode 180 finished. Total reward: 57.0 (57 timesteps)
# Episode 185 finished. Total reward: 40.0 (40 timesteps)
# Episode 190 finished. Total reward: 28.0 (28 timesteps)
# Updating the policy...
# Updating finished!
# Episode 195 finished. Total reward: 53.0 (53 timesteps)
# Episode 200 finished. Total reward: 100.0 (100 timesteps)
# Episode 205 finished. Total reward: 44.0 (44 timesteps)
# Episode 210 finished. Total reward: 26.0 (26 timesteps)
# Episode 215 finished. Total reward: 100.0 (100 timesteps)
# Episode 220 finished. Total reward: 18.0 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 225 finished. Total reward: 100.0 (100 timesteps)
# Episode 230 finished. Total reward: 100.0 (100 timesteps)
# Episode 235 finished. Total reward: 100.0 (100 timesteps)
# Episode 240 finished. Total reward: 100.0 (100 timesteps)
# Episode 245 finished. Total reward: 50.0 (50 timesteps)
# Episode 250 finished. Total reward: 18.0 (18 timesteps)
# Episode 255 finished. Total reward: 55.0 (55 timesteps)
# Updating the policy...
# Updating finished!
# Episode 260 finished. Total reward: 70.0 (70 timesteps)
# Episode 265 finished. Total reward: 100.0 (100 timesteps)
# Episode 270 finished. Total reward: 100.0 (100 timesteps)
# Episode 275 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 280 finished. Total reward: 100.0 (100 timesteps)
# Episode 285 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 100.0 (100 timesteps)
# Episode 295 finished. Total reward: 82.0 (82 timesteps)
# Updating the policy...
# Updating finished!
# Episode 300 finished. Total reward: 100.0 (100 timesteps)
# Episode 305 finished. Total reward: 100.0 (100 timesteps)
# Episode 310 finished. Total reward: 51.0 (51 timesteps)
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 320 finished. Total reward: 100.0 (100 timesteps)
# Episode 325 finished. Total reward: 100.0 (100 timesteps)
# Episode 330 finished. Total reward: 100.0 (100 timesteps)
# Episode 335 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 340 finished. Total reward: 100.0 (100 timesteps)
# Episode 345 finished. Total reward: 53.0 (53 timesteps)
# Episode 350 finished. Total reward: 100.0 (100 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Episode 360 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 365 finished. Total reward: 100.0 (100 timesteps)
# Episode 370 finished. Total reward: 100.0 (100 timesteps)
# Episode 375 finished. Total reward: 100.0 (100 timesteps)
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 100.0 (100 timesteps)
# Episode 400 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Episode 410 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 425 finished. Total reward: 100.0 (100 timesteps)
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Episode 440 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 445 finished. Total reward: 38.0 (38 timesteps)
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 100.0 (100 timesteps)
# Episode 460 finished. Total reward: 20.0 (20 timesteps)
# Updating the policy...
# Updating finished!
# Episode 465 finished. Total reward: 100.0 (100 timesteps)
# Episode 470 finished. Total reward: 100.0 (100 timesteps)
# Episode 475 finished. Total reward: 100.0 (100 timesteps)
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Episode 490 finished. Total reward: 100.0 (100 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2025/ex1/results/model/CartPole-v1-model3_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  73
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model3_params.pt ...
# Testing...
# Test ep reward: 679.0 seed: 73
# Average test reward: 679.0 episode length: 679.0
# Model 3 (seed=73): Average test reward = 679.0
# Numpy/Torch/Random Seed:  99
# Configuration Settings: {'exp_name': 'ex1', 'seed': 99, 'env_name': 'CartPole-v1', 'model_name': 'CartPole-v1-model4', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 16.0 (16 timesteps)
# Episode 5 finished. Total reward: 13.0 (13 timesteps)
# Episode 10 finished. Total reward: 14.0 (14 timesteps)
# Episode 15 finished. Total reward: 46.0 (46 timesteps)
# Episode 20 finished. Total reward: 14.0 (14 timesteps)
# Episode 25 finished. Total reward: 15.0 (15 timesteps)
# Episode 30 finished. Total reward: 10.0 (10 timesteps)
# Episode 35 finished. Total reward: 21.0 (21 timesteps)
# Episode 40 finished. Total reward: 14.0 (14 timesteps)
# Episode 45 finished. Total reward: 14.0 (14 timesteps)
# Episode 50 finished. Total reward: 39.0 (39 timesteps)
# Episode 55 finished. Total reward: 12.0 (12 timesteps)
# Episode 60 finished. Total reward: 23.0 (23 timesteps)
# Episode 65 finished. Total reward: 13.0 (13 timesteps)
# Episode 70 finished. Total reward: 13.0 (13 timesteps)
# Episode 75 finished. Total reward: 10.0 (10 timesteps)
# Episode 80 finished. Total reward: 14.0 (14 timesteps)
# Episode 85 finished. Total reward: 14.0 (14 timesteps)
# Episode 90 finished. Total reward: 11.0 (11 timesteps)
# Updating the policy...
# Updating finished!
# Episode 95 finished. Total reward: 31.0 (31 timesteps)
# Episode 100 finished. Total reward: 28.0 (28 timesteps)
# Episode 105 finished. Total reward: 32.0 (32 timesteps)
# Episode 110 finished. Total reward: 11.0 (11 timesteps)
# Episode 115 finished. Total reward: 13.0 (13 timesteps)
# Episode 120 finished. Total reward: 36.0 (36 timesteps)
# Episode 125 finished. Total reward: 32.0 (32 timesteps)
# Episode 130 finished. Total reward: 23.0 (23 timesteps)
# Episode 135 finished. Total reward: 29.0 (29 timesteps)
# Episode 140 finished. Total reward: 60.0 (60 timesteps)
# Episode 145 finished. Total reward: 10.0 (10 timesteps)
# Episode 150 finished. Total reward: 23.0 (23 timesteps)
# Episode 155 finished. Total reward: 56.0 (56 timesteps)
# Episode 160 finished. Total reward: 16.0 (16 timesteps)
# Updating the policy...
# Updating finished!
# Episode 165 finished. Total reward: 27.0 (27 timesteps)
# Episode 170 finished. Total reward: 57.0 (57 timesteps)
# Episode 175 finished. Total reward: 30.0 (30 timesteps)
# Episode 180 finished. Total reward: 75.0 (75 timesteps)
# Episode 185 finished. Total reward: 52.0 (52 timesteps)
# Episode 190 finished. Total reward: 40.0 (40 timesteps)
# Episode 195 finished. Total reward: 83.0 (83 timesteps)
# Episode 200 finished. Total reward: 40.0 (40 timesteps)
# Episode 205 finished. Total reward: 29.0 (29 timesteps)
# Updating the policy...
# Updating finished!
# Episode 210 finished. Total reward: 20.0 (20 timesteps)
# Episode 215 finished. Total reward: 100.0 (100 timesteps)
# Episode 220 finished. Total reward: 70.0 (70 timesteps)
# Episode 225 finished. Total reward: 100.0 (100 timesteps)
# Episode 230 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 235 finished. Total reward: 100.0 (100 timesteps)
# Episode 240 finished. Total reward: 100.0 (100 timesteps)
# Episode 245 finished. Total reward: 24.0 (24 timesteps)
# Episode 250 finished. Total reward: 24.0 (24 timesteps)
# Episode 255 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 260 finished. Total reward: 100.0 (100 timesteps)
# Episode 265 finished. Total reward: 100.0 (100 timesteps)
# Episode 270 finished. Total reward: 16.0 (16 timesteps)
# Episode 275 finished. Total reward: 68.0 (68 timesteps)
# Episode 280 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 285 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 100.0 (100 timesteps)
# Episode 295 finished. Total reward: 100.0 (100 timesteps)
# Episode 300 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 305 finished. Total reward: 100.0 (100 timesteps)
# Episode 310 finished. Total reward: 100.0 (100 timesteps)
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Episode 320 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 325 finished. Total reward: 100.0 (100 timesteps)
# Episode 330 finished. Total reward: 100.0 (100 timesteps)
# Episode 335 finished. Total reward: 83.0 (83 timesteps)
# Episode 340 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 345 finished. Total reward: 100.0 (100 timesteps)
# Episode 350 finished. Total reward: 100.0 (100 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Episode 360 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 365 finished. Total reward: 100.0 (100 timesteps)
# Episode 370 finished. Total reward: 45.0 (45 timesteps)
# Episode 375 finished. Total reward: 38.0 (38 timesteps)
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 100.0 (100 timesteps)
# Episode 400 finished. Total reward: 43.0 (43 timesteps)
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 410 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Episode 425 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Episode 440 finished. Total reward: 100.0 (100 timesteps)
# Episode 445 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 100.0 (100 timesteps)
# Episode 460 finished. Total reward: 100.0 (100 timesteps)
# Episode 465 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 470 finished. Total reward: 96.0 (96 timesteps)
# Episode 475 finished. Total reward: 100.0 (100 timesteps)
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 490 finished. Total reward: 100.0 (100 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2025/ex1/results/model/CartPole-v1-model4_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  99
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model4_params.pt ...
# Testing...
# Test ep reward: 120.0 seed: 99
# Average test reward: 120.0 episode length: 120.0
# Model 4 (seed=99): Average test reward = 120.0

# %% [markdown]
# Do not delete the cell below as it is used for grading.

# %%
# %%capture --no-stdout
test_seeds = [700, 800, 900, 1000, 2000]

for i in range(5):
    for seed in test_seeds:
        assert t.test(episodes=1, cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
            cfg_args=dict(testing=True, seed=seed,save_video=False, save_logging=False, 
            save_model=False, max_episode_steps=1000, model_name=str("CartPole-v1-model"+str(i)))) > 100
# Out:
# Numpy/Torch/Random Seed:  700
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model0_params.pt ...
# Testing...
# Test ep reward: 111.0 seed: 700
# Average test reward: 111.0 episode length: 111.0
# Numpy/Torch/Random Seed:  800
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model0_params.pt ...
# Testing...
# Test ep reward: 119.0 seed: 800
# Average test reward: 119.0 episode length: 119.0
# Numpy/Torch/Random Seed:  900
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model0_params.pt ...
# Testing...
# Test ep reward: 115.0 seed: 900
# Average test reward: 115.0 episode length: 115.0
# Numpy/Torch/Random Seed:  1000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model0_params.pt ...
# Testing...
# Test ep reward: 118.0 seed: 1000
# Average test reward: 118.0 episode length: 118.0
# Numpy/Torch/Random Seed:  2000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model0_params.pt ...
# Testing...
# Test ep reward: 125.0 seed: 2000
# Average test reward: 125.0 episode length: 125.0
# Numpy/Torch/Random Seed:  700
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model1_params.pt ...
# Testing...
# Test ep reward: 167.0 seed: 700
# Average test reward: 167.0 episode length: 167.0
# Numpy/Torch/Random Seed:  800
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model1_params.pt ...
# Testing...
# Test ep reward: 147.0 seed: 800
# Average test reward: 147.0 episode length: 147.0
# Numpy/Torch/Random Seed:  900
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model1_params.pt ...
# Testing...
# Test ep reward: 167.0 seed: 900
# Average test reward: 167.0 episode length: 167.0
# Numpy/Torch/Random Seed:  1000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model1_params.pt ...
# Testing...
# Test ep reward: 147.0 seed: 1000
# Average test reward: 147.0 episode length: 147.0
# Numpy/Torch/Random Seed:  2000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model1_params.pt ...
# Testing...
# Test ep reward: 141.0 seed: 2000
# Average test reward: 141.0 episode length: 141.0
# Numpy/Torch/Random Seed:  700
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model2_params.pt ...
# Testing...
# Test ep reward: 122.0 seed: 700
# Average test reward: 122.0 episode length: 122.0
# Numpy/Torch/Random Seed:  800
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model2_params.pt ...
# Testing...
# Test ep reward: 134.0 seed: 800
# Average test reward: 134.0 episode length: 134.0
# Numpy/Torch/Random Seed:  900
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model2_params.pt ...
# Testing...
# Test ep reward: 127.0 seed: 900
# Average test reward: 127.0 episode length: 127.0
# Numpy/Torch/Random Seed:  1000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model2_params.pt ...
# Testing...
# Test ep reward: 135.0 seed: 1000
# Average test reward: 135.0 episode length: 135.0
# Numpy/Torch/Random Seed:  2000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model2_params.pt ...
# Testing...
# Test ep reward: 141.0 seed: 2000
# Average test reward: 141.0 episode length: 141.0
# Numpy/Torch/Random Seed:  700
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model3_params.pt ...
# Testing...
# Test ep reward: 283.0 seed: 700
# Average test reward: 283.0 episode length: 283.0
# Numpy/Torch/Random Seed:  800
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model3_params.pt ...
# Testing...
# Test ep reward: 587.0 seed: 800
# Average test reward: 587.0 episode length: 587.0
# Numpy/Torch/Random Seed:  900
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model3_params.pt ...
# Testing...
# Test ep reward: 599.0 seed: 900
# Average test reward: 599.0 episode length: 599.0
# Numpy/Torch/Random Seed:  1000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model3_params.pt ...
# Testing...
# Test ep reward: 428.0 seed: 1000
# Average test reward: 428.0 episode length: 428.0
# Numpy/Torch/Random Seed:  2000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model3_params.pt ...
# Testing...
# Test ep reward: 303.0 seed: 2000
# Average test reward: 303.0 episode length: 303.0
# Numpy/Torch/Random Seed:  700
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model4_params.pt ...
# Testing...
# Test ep reward: 115.0 seed: 700
# Average test reward: 115.0 episode length: 115.0
# Numpy/Torch/Random Seed:  800
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model4_params.pt ...
# Testing...
# Test ep reward: 126.0 seed: 800
# Average test reward: 126.0 episode length: 126.0
# Numpy/Torch/Random Seed:  900
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model4_params.pt ...
# Testing...
# Test ep reward: 120.0 seed: 900
# Average test reward: 120.0 episode length: 120.0
# Numpy/Torch/Random Seed:  1000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model4_params.pt ...
# Testing...
# Test ep reward: 121.0 seed: 1000
# Average test reward: 121.0 episode length: 121.0
# Numpy/Torch/Random Seed:  2000
# Loading model from /notebooks/rl2025/ex1/results/model/CartPole-v1-model4_params.pt ...
# Testing...
# Test ep reward: 131.0 seed: 2000
# Average test reward: 131.0 episode length: 131.0

# %% [markdown]
# **DOUBLE CLICK HERE TO EDIT, CLEAR THIS TEXT AND REPORT HERE**
# *   **Model 0 (seed=10):** Average test reward = 110.0
# *   **Model 1 (seed=25):** Average test reward = 138.0
# *   **Model 2 (seed=42):** Average test reward = 118.0
# *   **Model 3 (seed=73):** Average test reward = 679.0
# *   **Model 4 (seed=99):** Average test reward = 120.0

# %% [markdown]
# <a id='Q2'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 2.1</b> Analysis of Training Performance (15 points) </h3>
#
# Are the behavior and performance of the trained models the same every time? Why/why not? Analyze the causes briefly. Hint: the random seed initializes the weights and the environment settings randomly.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# Select all the correct answers. You get 3 points for each correct answer. Select at **most** 6 answers, or you will **lose all points**.
#
# 1. Yes, because the model has been optimized to always reach the highest possible reward regardless of random seeds or initial conditions.
#
# 2. No, because the training dynamics and the evaluating dynamics are not the same
#
# 3. No, because the trained model has stochastic behaviour which may perform differently in different environments
#
# 4. No, the behaviour and performance are not the same, as shown by the different average rewards in previous Task.
#
# 5. No, because there’s a lot of stochasticity involved in the training process
#
# 6. No, because agent explores with random actions during training
#
# 7. No, because policy is initially randomly initialised with random weights, gradient updates of the policy are noisy.
#
# 8. No, because the environment may be stochastic: agent is randomly initialised in beginning of each episode, (transitions from one state to next one may follow a probability distribution)
#
# 9. Yes, all machine learning models perform consistently after training due to the deterministic nature of their algorithms.

# %%
sq2_1 = [2, 4, 5, 7, 8] # Answer question 2.1 with the appropriate answer numbers

# %%
assert 1 <= len(set(sq2_1)) <= 6
assert set(sq2_1) < set(range(1, 10))

# %% [markdown]
# Do not remove the following blocks as they are used for grading

# %% [markdown]
# <a id='Q3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 2.2</b> Stochasticity (10 points) </h3>
#
# What are the implications of this stochasticity, when it comes to comparing reinforcement learning algorithms to each other?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# Select **only one**:
#
# 1. It is only necessary to compare the maximum rewards achieved by each algorithm to determine the best one.
#
# 2. Stochasticity requires that algorithms be trained and evaluated multiple times to obtain a reliable estimate of performance, including measures of variance besides the average reward.
#
# 3. Algorithms should be trained once under identical conditions to ensure a fair comparison, focusing on the consistency of the training process.
#
# 4. The best approach is to evaluate algorithms based on their performance in a single, well-designed test to avoid the confounding effects of random variability.

# %%
sq2_2 = 2 # Answer question 2.2 with the appropriate answer number

# %%
assert sq2_2 in range(1,5)

# %% [markdown]
# The following cells are used for grading

# %% [markdown]
# # Reacher <a id='3.'></a>
#
# Now we will focus on designing a reward function for a different environment, the Reacher environment, where a two-joint manipulator needs to reach a goal (see Figure 2).
#
# <figure>
# <img src="imgs/reacher.png" width="200px">
# <figcaption style="text-align: center"> Figure 2: The Reacher environment  </figcaption>
# </figure>
#
# The Cartesian ($x$, $y$) position of the end-effector of the manipulator can be determined following the equation:
#
# $$
#  x = L_1 \sin(\theta_0)+L_2 \sin(\theta_0+\theta_1)\\
#  y = -L_1 \cos(\theta_0)-L_2 \cos(\theta_0+\theta_1)
# $$
#
# where $L1 = 1$, $L2 = 1$ are the lengths, and $\theta_0$, $\theta_1$ the joint angles of the first and second links respectively. The state (and observation) in this environment is the two element vector:
#
# $$
# o=s=\left(\begin{array}{c}
# \theta_0 \\
# \theta_1 \\
# \end{array}\right) \text {, }
# $$
#
# The action space now consists of 5 "options"; 4 correspond rotating the first/second joint left/right, and the final one performs no motion at all (the configuration doesn’t change). The episode terminates when the agent reaches the target position, marked in red. Now, let us design a custom reward function and use it for training the RL agent.

# %% [markdown]
# <a id='T3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 3.</b> Reward Functions (20 points) </h3>
#
# Below two classes are shown that modify the reward function of the reacher function provided in ```reacher.py```. Edit the function ```get_reward``` _below_ (not in ```reacher.py```) in both classes. For each class, write a reward function to incentivise the agent to learn the following behaviors:
#
# Class 1) ```SpinningReacherEnv```: Keep the manipulator rotating clockwise continuously (w.r.t. angle θ_0). You can use a lower number of training episodes for this, e.g. train(cfg_args=dict(env_name='SpinningReacher-v0', train_episodes=200), overrides=['env=reacher_v1'])
#
# Class 2) ```TargetReacherEnv```: Reach the goal point located in x = [1.0,1.0] (marked in red). Use at least 500 training episodes.
#
# Train one model for each behavior.
#
# **Hint:** Use the observation vector to get the quantities required to compute the new reward (such as the position of the manipulator). You can get the Cartesian position of the end-effector with ```self.get_cartesian_pos(state)```.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
from reacher import ReacherEnv
from typing import Optional
from gymnasium.envs.registration import register

class SpinningReacherEnv(ReacherEnv):
    def __init__(self, render_mode: Optional[str] = None, max_episode_steps=200):
        super().__init__(render_mode=render_mode, max_episode_steps=max_episode_steps)
        
    def get_reward(self, prev_state, action, next_state):
        '''
        TODO: Task 3: Implement and test the first reward function
        '''
        # Get the change in theta_0 (first joint angle)
        theta0_prev = prev_state[0]
        theta0_next = next_state[0]
        
        # Calculate angular change
        delta_theta = theta0_next - theta0_prev
        
        # Handle angle wrapping (from -pi to pi)
        if delta_theta > np.pi:
            delta_theta -= 2 * np.pi
        elif delta_theta < -np.pi:
            delta_theta += 2 * np.pi
        
        # Reward negative change (clockwise rotation)
        # Larger negative change = higher reward
        if delta_theta < 0:
            reward = -delta_theta * 10  # Scale the reward
        else:
            reward = delta_theta * -2  # Penalize counter-clockwise
            
        return reward
    
register("SpinningReacher-v0",
        entry_point="%s:SpinningReacherEnv"%__name__,
        max_episode_steps=200)

class TargetReacherEnv(ReacherEnv):
    def __init__(self, render_mode: Optional[str] = None, max_episode_steps=200):
        super().__init__(render_mode=render_mode, max_episode_steps=max_episode_steps)
        
    def get_reward(self, prev_state, action, next_state):
        '''
        # TODO: Task 3: Implement and test the second reward function
        '''
        # Get current end-effector position
        current_pos = self.get_cartesian_pos(next_state)
        
        # Target position
        target = np.array([1.0, 1.0])
        
        # Calculate distance to target
        distance = np.linalg.norm(current_pos - target)
        
        # Reward is negative distance (closer = higher reward)
        # Scale and add bonus for very close positions
        reward = -distance
        
        # Add bonus reward for being very close to target
        if distance < 0.1:
            reward += 10.0
        elif distance < 0.3:
            reward += 2.0
            
        return reward
        
register("TargetReacher-v0",
        entry_point="%s:TargetReacherEnv"%__name__,
        max_episode_steps=200)

# %%
if not skip_training:
      t.train(cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
      cfg_args=dict(env_name='SpinningReacher-v0',model_name='SpinningReacher-v0', train_episodes=200, seed=1)) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  1
# Configuration Settings: {'exp_name': 'ex1', 'seed': 1, 'env_name': 'SpinningReacher-v0', 'model_name': 'SpinningReacher-v0', 'max_episode_steps': 200, 'train_episodes': 200, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 2
# Action space dimensions: 5
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:87: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2025/ex1/results/video/SpinningReacher-v0/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episode 0 finished. Total reward: 63.599984377622604 (200 timesteps)
# Episode 5 finished. Total reward: 89.9999289214611 (200 timesteps)
# Episode 10 finished. Total reward: 67.59998708963394 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 15 finished. Total reward: 65.59994694590569 (200 timesteps)
# Episode 20 finished. Total reward: 65.59998741745949 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 25 finished. Total reward: 60.39995023608208 (100 timesteps)
# Episode 30 finished. Total reward: 118.79991611838341 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 35 finished. Total reward: 200.80249354243279 (200 timesteps)
# Episode 40 finished. Total reward: 166.0013230741024 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 45 finished. Total reward: 197.60222801566124 (200 timesteps)
# Episode 50 finished. Total reward: 240.4034741818905 (185 timesteps)
# Episode 55 finished. Total reward: 114.40022084116936 (142 timesteps)
# Updating the policy...
# Updating finished!
# Episode 60 finished. Total reward: 112.80056163668633 (88 timesteps)
# Episode 65 finished. Total reward: 57.19995340704918 (67 timesteps)
# Episode 70 finished. Total reward: 118.4006516635418 (101 timesteps)
# Updating the policy...
# Updating finished!
# Episode 75 finished. Total reward: 280.8043210208416 (200 timesteps)
# Episode 80 finished. Total reward: 49.199959486722946 (43 timesteps)
# Episode 85 finished. Total reward: 116.40060743689537 (95 timesteps)
# Updating the policy...
# Updating finished!
# Episode 90 finished. Total reward: 306.805030554533 (200 timesteps)
# Episode 95 finished. Total reward: 306.00501224398613 (180 timesteps)
# Episode 100 finished. Total reward: 109.60056468844414 (74 timesteps)
# Updating the policy...
# Updating finished!
# Episode 105 finished. Total reward: 355.20621463656425 (200 timesteps)
# Episode 110 finished. Total reward: 357.2062222659588 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 115 finished. Total reward: 379.20672580599785 (200 timesteps)
# Episode 120 finished. Total reward: 362.8063504397869 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 125 finished. Total reward: 221.60311862826347 (123 timesteps)
# Episode 130 finished. Total reward: 222.00316593050957 (128 timesteps)
# Episode 135 finished. Total reward: 220.00312015414238 (122 timesteps)
# Updating the policy...
# Updating finished!
# Episode 140 finished. Total reward: 355.6062237918377 (200 timesteps)
# Episode 145 finished. Total reward: 282.0045392215252 (156 timesteps)
# Updating the policy...
# Updating finished!
# Episode 150 finished. Total reward: 282.0045392215252 (152 timesteps)
# Episode 155 finished. Total reward: 344.005958288908 (196 timesteps)
# Episode 160 finished. Total reward: 351.6061322391033 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 165 finished. Total reward: 284.0045849978924 (155 timesteps)
# Episode 170 finished. Total reward: 285.6045834720135 (162 timesteps)
# Updating the policy...
# Updating finished!
# Episode 175 finished. Total reward: 282.0045392215252 (153 timesteps)
# Episode 180 finished. Total reward: 346.0060040652752 (193 timesteps)
# Updating the policy...
# Updating finished!
# Episode 185 finished. Total reward: 366.00646182894707 (200 timesteps)
# Episode 190 finished. Total reward: 380.0067822635174 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 195 finished. Total reward: 379.2067639529705 (200 timesteps)
# Episode 200 finished. Total reward: 385.6069104373455 (200 timesteps)
# Model saved to /notebooks/rl2025/ex1/results/model/SpinningReacher-v0_params.pt
# ------Training finished.------

# %%
if not skip_training:
       t.test(episodes=10, cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
       cfg_args=dict(env_name='SpinningReacher-v0',model_name='SpinningReacher-v0', testing=True,seed=None))
# Out:
# Numpy/Torch/Random Seed:  501
# Loading model from /notebooks/rl2025/ex1/results/model/SpinningReacher-v0_params.pt ...
# Testing...
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:87: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2025/ex1/results/video/SpinningReacher-v0/test folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test ep reward: 400.00724002718925 seed: 88
# Test ep reward: 400.0072306394577 seed: 672
# Test ep reward: 400.0072440505028 seed: 680
# Test ep reward: 400.0072667002678 seed: 592
# Test ep reward: 400.00723868608475 seed: 481
# Test ep reward: 400.00725135207176 seed: 78
# Test ep reward: 400.0072477757931 seed: 735
# Test ep reward: 400.00722020864487 seed: 852
# Test ep reward: 400.0072579085827 seed: 694
# Test ep reward: 400.00724345445633 seed: 965
# Average test reward: 400.0072440803051 episode length: 200.0

# %% [markdown]
# The agent acting in the environment can be seen using the following command. Change the ```path``` to pick the episode you want to visualize. Bear in mind by default video saving for training is taken every 50 episodes.

# %%
if not skip_training:
      video = Video(work_dir/'video'/'SpinningReacher-v0'/'test'/f'ex1-episode-0.mp4',
      embed=True, html_attributes="loop autoplay") # Set html_attributes="controls" for video control
      display(video)
# Out:
# <video loop autoplay  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
if not skip_training:
      t.train(cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
      cfg_args=dict(env_name='TargetReacher-v0',model_name='TargetReacher-v0', train_episodes=500, seed=1)) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  1
# Configuration Settings: {'exp_name': 'ex1', 'seed': 1, 'env_name': 'TargetReacher-v0', 'model_name': 'TargetReacher-v0', 'max_episode_steps': 200, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 2
# Action space dimensions: 5
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:87: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2025/ex1/results/video/TargetReacher-v0/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episode 0 finished. Total reward: -571.9537799663696 (200 timesteps)
# Episode 5 finished. Total reward: -533.6843767599244 (200 timesteps)
# Episode 10 finished. Total reward: -604.2727677112639 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 15 finished. Total reward: -82.49677416800309 (43 timesteps)
# Episode 20 finished. Total reward: -369.8773110116718 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 25 finished. Total reward: -404.19739335562537 (196 timesteps)
# Episode 30 finished. Total reward: -384.44742760366904 (200 timesteps)
# Episode 35 finished. Total reward: -349.1152041706242 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 40 finished. Total reward: -334.2312662602258 (176 timesteps)
# Episode 45 finished. Total reward: -125.46550052413863 (80 timesteps)
# Episode 50 finished. Total reward: -278.43288092784553 (163 timesteps)
# Updating the policy...
# Updating finished!
# Episode 55 finished. Total reward: -102.44187002244381 (46 timesteps)
# Episode 60 finished. Total reward: -54.45672923654708 (33 timesteps)
# Episode 65 finished. Total reward: -119.72996152150111 (78 timesteps)
# Updating the policy...
# Updating finished!
# Episode 70 finished. Total reward: -368.181885668887 (200 timesteps)
# Episode 75 finished. Total reward: -47.25308963430054 (30 timesteps)
# Episode 80 finished. Total reward: -73.07423226347262 (37 timesteps)
# Episode 85 finished. Total reward: -341.134864353524 (200 timesteps)
# Episode 90 finished. Total reward: -129.4793533086033 (79 timesteps)
# Updating the policy...
# Updating finished!
# Episode 95 finished. Total reward: -150.5976587733958 (93 timesteps)
# Episode 100 finished. Total reward: -31.972619271132086 (21 timesteps)
# Episode 105 finished. Total reward: -359.6631987826455 (200 timesteps)
# Episode 110 finished. Total reward: -155.28839782644707 (98 timesteps)
# Episode 115 finished. Total reward: -51.17550565205014 (30 timesteps)
# Updating the policy...
# Updating finished!
# Episode 120 finished. Total reward: -346.8003275482138 (200 timesteps)
# Episode 125 finished. Total reward: -51.5000221161525 (31 timesteps)
# Episode 130 finished. Total reward: -370.974560077343 (190 timesteps)
# Episode 135 finished. Total reward: -340.3109542862179 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 140 finished. Total reward: -365.35546898714955 (200 timesteps)
# Episode 145 finished. Total reward: -380.11345465708996 (200 timesteps)
# Episode 150 finished. Total reward: -394.5758026780507 (200 timesteps)
# Episode 155 finished. Total reward: -382.5189005082181 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 160 finished. Total reward: -373.6684058281977 (200 timesteps)
# Episode 165 finished. Total reward: -152.96935710674805 (93 timesteps)
# Episode 170 finished. Total reward: -26.972639545103693 (17 timesteps)
# Episode 175 finished. Total reward: -392.8483135627255 (200 timesteps)
# Episode 180 finished. Total reward: -148.09096593664776 (95 timesteps)
# Episode 185 finished. Total reward: -36.385904290834176 (20 timesteps)
# Updating the policy...
# Updating finished!
# Episode 190 finished. Total reward: -143.1132385883634 (88 timesteps)
# Episode 195 finished. Total reward: -25.868680634880704 (18 timesteps)
# Episode 200 finished. Total reward: -20.556692812079874 (18 timesteps)
# Episode 205 finished. Total reward: -116.94972947987858 (83 timesteps)
# Episode 210 finished. Total reward: -287.18770277754163 (163 timesteps)
# Updating the policy...
# Updating finished!
# Episode 215 finished. Total reward: -15.476533346035309 (15 timesteps)
# Episode 220 finished. Total reward: -122.0836773555596 (78 timesteps)
# Episode 225 finished. Total reward: -32.498027369292075 (17 timesteps)
# Episode 230 finished. Total reward: -54.4603913099425 (44 timesteps)
# Episode 235 finished. Total reward: -378.03428929178415 (200 timesteps)
# Episode 240 finished. Total reward: -385.15618080703064 (200 timesteps)
# Episode 245 finished. Total reward: -25.876155810354717 (17 timesteps)
# Updating the policy...
# Updating finished!
# Episode 250 finished. Total reward: -41.259982726483486 (24 timesteps)
# Episode 255 finished. Total reward: -369.6391547902496 (192 timesteps)
# Episode 260 finished. Total reward: -24.53244883885973 (19 timesteps)
# Episode 265 finished. Total reward: -31.786895787058125 (18 timesteps)
# Episode 270 finished. Total reward: -28.72607984081774 (17 timesteps)
# Episode 275 finished. Total reward: -28.648351135357586 (17 timesteps)
# Episode 280 finished. Total reward: -26.65782552551358 (17 timesteps)
# Episode 285 finished. Total reward: -28.477484388976873 (18 timesteps)
# Episode 290 finished. Total reward: -26.53675649512077 (16 timesteps)
# Episode 295 finished. Total reward: -22.355937989502593 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 300 finished. Total reward: -23.325140860424334 (16 timesteps)
# Episode 305 finished. Total reward: -24.426952579684325 (16 timesteps)
# Episode 310 finished. Total reward: -31.31392606497782 (19 timesteps)
# Episode 315 finished. Total reward: -117.7320915094457 (78 timesteps)
# Episode 320 finished. Total reward: -29.370276993911606 (18 timesteps)
# Episode 325 finished. Total reward: -23.836254846785238 (15 timesteps)
# Episode 330 finished. Total reward: -381.29047870751737 (200 timesteps)
# Episode 335 finished. Total reward: -22.185197093792887 (14 timesteps)
# Updating the policy...
# Updating finished!
# Episode 340 finished. Total reward: -22.84842099095116 (15 timesteps)
# Episode 345 finished. Total reward: -378.95475000665294 (200 timesteps)
# Episode 350 finished. Total reward: -381.92085494576617 (200 timesteps)
# Episode 355 finished. Total reward: -31.20893445987876 (18 timesteps)
# Episode 360 finished. Total reward: -25.91797420334279 (15 timesteps)
# Episode 365 finished. Total reward: -17.366523198631484 (16 timesteps)
# Episode 370 finished. Total reward: -392.78490109761725 (200 timesteps)
# Episode 375 finished. Total reward: -25.57100017753747 (17 timesteps)
# Episode 380 finished. Total reward: -27.83916857293695 (16 timesteps)
# Updating the policy...
# Updating finished!
# Episode 385 finished. Total reward: -366.64724741557745 (200 timesteps)
# Episode 390 finished. Total reward: -15.101686525704102 (15 timesteps)
# Episode 395 finished. Total reward: -369.4461759993554 (200 timesteps)
# Episode 400 finished. Total reward: -17.321006136541342 (16 timesteps)
# Episode 405 finished. Total reward: -22.49404496341031 (14 timesteps)
# Episode 410 finished. Total reward: -26.243373196679087 (17 timesteps)
# Episode 415 finished. Total reward: -112.67767738447127 (77 timesteps)
# Episode 420 finished. Total reward: -15.751660472498196 (16 timesteps)
# Updating the policy...
# Updating finished!
# Episode 425 finished. Total reward: -389.7621708326779 (200 timesteps)
# Episode 430 finished. Total reward: -20.279845690700895 (17 timesteps)
# Episode 435 finished. Total reward: -18.986335274244475 (17 timesteps)
# Episode 440 finished. Total reward: -22.202348564506895 (15 timesteps)
# Episode 445 finished. Total reward: -14.394328596910603 (15 timesteps)
# Episode 450 finished. Total reward: -23.453480389495574 (15 timesteps)
# Episode 455 finished. Total reward: -20.65381093863734 (16 timesteps)
# Episode 460 finished. Total reward: -23.2020910401414 (15 timesteps)
# Episode 465 finished. Total reward: -24.521758289502614 (16 timesteps)
# Episode 470 finished. Total reward: -24.31371467320105 (15 timesteps)
# Episode 475 finished. Total reward: -22.974010955866824 (15 timesteps)
# Episode 480 finished. Total reward: -18.8401787410127 (16 timesteps)
# Episode 485 finished. Total reward: -26.812010404068275 (16 timesteps)
# Episode 490 finished. Total reward: -36.00300626817905 (19 timesteps)
# Updating the policy...
# Updating finished!
# Episode 495 finished. Total reward: -167.65958064881812 (111 timesteps)
# Episode 500 finished. Total reward: -22.92545870922787 (16 timesteps)
# Model saved to /notebooks/rl2025/ex1/results/model/TargetReacher-v0_params.pt
# ------Training finished.------

# %%
if not skip_training:
       t.test(episodes=10, cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
       cfg_args=dict(env_name='TargetReacher-v0',model_name='TargetReacher-v0', seed=None, testing=True,))
# Out:
# Numpy/Torch/Random Seed:  519
# Loading model from /notebooks/rl2025/ex1/results/model/TargetReacher-v0_params.pt ...
# Testing...
# Test ep reward: -27.084576224788545 seed: 25
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:87: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2025/ex1/results/video/TargetReacher-v0/test folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test ep reward: -25.929349175118674 seed: 466
# Test ep reward: -25.35843008274748 seed: 374
# Test ep reward: -23.79602701204887 seed: 517
# Test ep reward: -13.430969990078912 seed: 875
# Test ep reward: -23.660106693353466 seed: 180
# Test ep reward: -25.213505923097166 seed: 20
# Test ep reward: -26.95571251747465 seed: 519
# Test ep reward: -24.347106875900185 seed: 873
# Test ep reward: -22.325940831925177 seed: 768
# Average test reward: -23.81017253265331 episode length: 15.1

# %%
if not skip_training:
      video = Video(work_dir/'video'/'TargetReacher-v0'/'test'/f'ex1-episode-0.mp4',
      embed=True, html_attributes="loop autoplay") # Set html_attributes="controls" for video control
      display(video)
# Out:
# <video loop autoplay  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# Do not delete the following cells as they are used for grading. Make sure to test that both agents work correctly for the selected set of seeds [860, 241, 73, 543, 582, 211, 524, 484, 954, 656].

# %%
# %%capture --no-stdout
"TEST CELL"

# %%
# %%capture --no-stdout
"TEST CELL"

# %% [markdown]
# <a id='T4'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 4.</b> Visualizing Behavior </h3>
#
# Now, let us visualize the reward function for the second behavior (reaching the goal [1,1]). Plot the values of the second reward function from Task 3 and the learned best action as a function of the state (the joint positions). Use the code below as a starting point. After plotting, answer the questions below.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import gymnasium as gym
from agent import Agent, Policy

# %%
env_name = "TargetReacher-v0" 
resolution = 101  # Resolution of the policy/reward image

# Load policy from default path to plot
policy_dir = Path().cwd()/'results'/'model'/f'{env_name}_params.pt'

sns.set()

# Create a gym environment
env = gym.make(env_name)

action_space_dim = u.get_space_dim(env.action_space)
observation_space_dim = u.get_space_dim(env.observation_space)
policy = Policy(observation_space_dim, action_space_dim)

if policy_dir:
    policy.load_state_dict(torch.load(policy_dir))
    print("Loading policy from", policy_dir)
else:
    print("Plotting a random policy")
# Out:
# Loading policy from /notebooks/rl2025/ex1/results/model/TargetReacher-v0_params.pt

# %%
# Create a grid and initialize arrays to store rewards and actions
npoints = resolution
state_range = np.linspace(-np.pi, np.pi, npoints)
rewards = np.zeros((npoints, npoints))
actions = np.zeros((npoints, npoints), dtype=np.int32)

# Loop through state[0] and state[1]
for i,th1 in enumerate(state_range):
    for j,th2 in enumerate(state_range):
        # Create the state vector from th1, th2
        state = np.array([th1, th2])

        # Query the policy and find the most probable action
        with torch.no_grad():
            action_dist, _ = policy(torch.from_numpy(state).float().unsqueeze(0))
        action_probs = action_dist.probs.numpy()

        '''
        # TODO: Task 4: 
        # 1. What's the best action, according to the policy?
        # 2. Compute the reward given state
        '''
        ########## Your code starts here ##########
        # Use the action probabilities in the action_probs vector
        # (it's a numpy array)
        actions[i, j] = 0
        
        rewards[i,j] = 0 
                # 1. Best action according to policy (highest probability)
        actions[i, j] = np.argmax(action_probs[0])
        
        # 2. Compute reward for this state
        # Create a dummy environment instance to compute reward
        dummy_state = state
        dummy_action = 0  # Action doesn't matter for position-based reward
        rewards[i, j] = env.get_reward(dummy_state, dummy_action, dummy_state)
        ########## Your code ends here ##########

# %%
# Create the reward plot
num_ticks = 10
tick_skip = max(1, npoints // num_ticks)
tick_shift = 2*np.pi/npoints/2
tick_points = np.arange(npoints)[::tick_skip] + tick_shift
tick_labels = state_range.round(2)[::tick_skip]

sns.heatmap(rewards)
plt.xticks(tick_points, tick_labels, rotation=45)
plt.yticks(tick_points, tick_labels, rotation=45)
plt.xlabel("J2")
plt.ylabel("J1")
plt.title("Reward")
plt.suptitle("Rewards in %s" % env_name)
plt.show()

# %%
# # Create the policy plot
cmap = sns.color_palette("deep", action_space_dim)
sns.heatmap(actions, cmap=cmap, vmin=0, vmax=action_space_dim-1)
plt.xticks(tick_points, tick_labels, rotation=45)
plt.yticks(tick_points, tick_labels, rotation=45)
colorbar = plt.gca().collections[0].colorbar
ticks = np.array(range(action_space_dim))*((action_space_dim-1)/action_space_dim)+0.5
colorbar.set_ticks(ticks)
if env.spec.id == "Reacher-v1":
    # In Reacher, we can replace 0..4 with more readable labels
    labels = ["J1+", "J1-", "J2+", "J2-", "Stop"]
else:
    labels = list(map(str, range(action_space_dim)))
colorbar.set_ticklabels(labels)
plt.xlabel("J2")
plt.ylabel("J1")
plt.title("Best action")
plt.suptitle("Best action in %s" % env_name)
plt.show()

# %% [markdown]
# Do not remove this cell as it is used for grading

# %% [markdown]
# <a id='Q4'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.1</b> Achieved Performance (5 points) </h3>
#
# Where should the reward be higher for the reaching task?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# Select **only one**.
# 1. Reward should be higher when the end-effector is far from the goal.
# 2. Reward should be higher when the end-effector is near the goal.
# 3. Reward should be equal in joint space.
# 4. Reward should have noise to improve exploration and be higher when close to the goal.
# 5. Reward should be calculated based on the history, if end-effector is approaching the goal, it should be higher

# %%
sq4_1 = 2 # Answer question 4.1 with the appropriate answer number

# %%
assert sq4_1 in range(1, 6)

# %% [markdown]
# <a id='Q5'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.2</b> Analysis of Behaviour (9 points) </h3>
#
# Did the policy learn to reach the goal from every possible state (manipulator configuration) in an optimal way (i.e. with lowest possible number of steps)? Why/why not?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# Select all the correct answers. You get 3 points for each correct answer. Select at **most** 4 answers, or you will **lose all points**.
#
# 1. Yes, the policy efficiently learns to reach the goal from every state due to comprehensive state exploration.
#
# 2. No, the policy fails to explore all states adequately because the initial and goal states are nearly constant, leading to limited exploration ability.
#
# 3. Yes, the model is trained to always find the shortest path due to advanced algorithmic efficiency.
#
# 4. No, because the policy often chooses longer paths for certain initial states , not exploiting shorter alternatives.
#
# 5. Yes, continuous training ensures the policy adapts to find the best route from any state over time.
#
# 6. No, optimal paths are not always found because the exploration phase is limited, causing repeated suboptimal actions.
#
# 7. No, the policy sometimes achieves the goal optimally, but not consistently across all trials and configurations.
#
# 8. Yes, the training regime guarantees that all possible configurations are optimally addressed by the final model.
#
# 9. No, the policy cannot reach from all state because the policy has stochastic behavior.
#
# 10. No, bacause the policy overfits to the online it collects.
#
# 11. No, bacause the the reward function is not defined in an optimal way for this task.

# %%
sq4_2 = [2, 4, 6, 7] #Answer question 4.2 with the appropriate answer numbers

# %%
assert 1 <= len(set(sq4_2)) <= 4
assert set(sq4_2) < set(range(1, 12))

# %% [markdown]
# Do not remove the following blocks as they are used for grading

# %% [markdown]
# <a id='Q6'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.3</b> Checking your knowledge about RL (9 points) </h3>
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# Select all the true statements. You get 3 points for each correct answer. Select at **most** 4 answers, or you will **lose all points**.
#
# 1. Each trial in reinforcement learning is called an episode.
#
# 2. Each trial in reinforcement learning should have the same length.
#
# 3. Reinforcement learning always requires a model of the environment.
#
# 4. Once the agent learns, it never makes mistakes again.
#
# 5. Exploitation means choosing the action that seems best based on past experience.
#
# 6. Optimal policies are always found in reinforcement learining.
#
# 7. There is always only one optimal policy.
#
# 8. The exploration–exploitation trade-off is central to reinforcement learning.

# %%
sq4_3 = [1, 5, 8] #Answer question 4.2 with the appropriate answer numbers

# %%
assert 1 <= len(set(sq4_3)) <= 4
assert set(sq4_3) < set(range(1, 9))

# %% [markdown]
# # 5. Submitting <a id='4.'></a>
# Ensure all tasks and questions (in ```ex1.ipynb```) are answered and the relevant plots are recorded in the relevant places. Details about attaching images and figures can be found below. The relevant graphs to be included for this assignment are:
# - Task 1, CartPole ```episodesep_reward``` plot from logged csv file
# - x2 Task 4 reward plots
#
# Ensure the correct model files are saved:
# - results/model/CartPole-v1_params.pt
# - results/model/CartPole-v1-model{0-4}_params.pt
# - results/model/SpinningReacher-v0_params.pt
# - results/model/TargetReacher-v0_params.pt

# %%
# Make sure that skip training is set to True before submission
assert skip_training == True
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Make sure that skip training is set to True before submission
# ----> 2 assert skip_training == True
#
# AssertionError:

# %% [markdown]
# ## 5.1 Feedback <a id='5.1'></a>
#
# In order to help the staff of the course as well as the forthcoming students, it would be great if you could answer to the following questions in your submission:

# %% [markdown]
# 1) How much time did you spend solving this exercise? (change the ```hrs``` variable below to a floating point number representing the number of hours taken e.g. 5.43)

# %%
hrs = 3.39

# %% [markdown]
# 2) Difficulty of each task/question from 1-5 (int or float)

# %%
T1 = 1 # Student Task 1. Training a simple model for Cartpole environment
Q1_1 = 1 # Student Question 1.1 Learning
T2 = 1 # Student Task 2. Investigating training performance
Q2_1 = 1 # Student Question 2.1 Analyzing the training performance
Q2_2 = 3 # Stochasticity
T3 = 3 # Student Task 3. Reward function
T4 = 2 # Student Task 4. Visualize behavior
Q4_1 = 2 # Student Question 4.1 Achieved performance
Q4_2 = 3 # Student Question 4.2 Analysis of behavior
Q4_3 = 2 # Student Question 4.3 Checking your knowledge about RL

# %% [markdown]
# 3) How well did you understand the content of the task/question from 1-5? (int or float)

# %%
T1 = 1 # Student Task 1. Training a simple model for Cartpole environment
Q1_1 = 1 # Student Question 1.1 Learning
T2 = 2 # Student Task 2. Investigating training performance
Q2_1 = 3 # Student Question 2.1 Analyzing the training performance
Q2_2 = 3 # Stochasticity
T3 = 3 # Student Task 3. Reward function
T4 = 3 # Student Task 4. Visualize behavior
Q4_1 = 3 # Student Question 4.1 Achieved performance
Q4_2 = 3 # Student Question 4.2 Analysis of behavior
Q4_3 = 2 # Student Question 4.3 Checking your knowledge about RL

# %% [markdown]
# 4) General feedback. Consider questions like:
#
#     - Did the content of the lecture relate well with the assignment?
#     - To what extent did you find the material to be potentially useful for your research and studies?
#
# And other feedback you think is worth including. Type in the box below

# %% [markdown]
# I found this lecture really engaging and enjoyable. The content connected well with the assignment, and the examples were clear and easy to follow. I especially appreciated the way complex ideas were explained in a vivid and interesting way. I can see that these concepts will be useful for my research and studies.

# %% [markdown]
# # References <a id='5.'></a>
#
# [1] Sutton, Richard S., and Andrew G. Barto. "Reinforcement Learning: An Introduction (in progress)." London, England (2017). http://incompleteideas.net/book/RLbook2018.pdf
